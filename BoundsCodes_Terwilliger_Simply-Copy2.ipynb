# %%
import numpy as np
import math
import itertools
import picos as pic
import mosek

# %%
def K_fun(m,k,n):

    Fun=0

    for q in range(0,m+1):
        Fun+= math.comb(n-k,m-q)*math.comb(k,q)*(-1)**q
    return Fun

# %%
def SDP(n,K,d,p,D):
    
    ##### SDP #####

    T=2**p
    
    pic.available_solvers()
    
    
    Ap = pic.RealVariable("Ap", n+1)
    
    sdp = pic.Problem()

    sdp.set_objective('find')
    
    L=1e5
    
    sdp.add_constraint(Ap[0]==L)
    sdp.add_constraint(Ap[n]==L/K)
    
    sdp.add_list_of_constraints((K*Ap[n-i]-Ap[i])== 0 for i in range(d)) 

    for m in range(n+1):
        A=0
        for j in range(m+1):
            A+=(-1)**(m-j)*D**(j)*math.comb(n-j,n-m)*Ap[j]
        sdp.add_constraint(A>=0)            
    
    
    ### K*B_j-A_j>=0 ###
    for m in range(n+1):   
                                    
        sdp.add_constraint(                              
        sum((-1)**(m-j)*D**(j)*math.comb(n-j,n-m)*(K*Ap[n-j]-Ap[j]) for j in range(m+1)) >= 0)
    
    ### sum(K_j*A'_j)>=0 ###
    
    for j in range(n+1):
        sdp.add_constraint(sum(K_fun(n-j,i,n)*Ap[i] for i in range(n+1)) >= 0)
    
    
    #print(sdp.variables)
    
    sol = sdp.solve(solver='mosek', primals=False)


    if sol.problemStatus == "feasible":
        return True                    
    elif sol.problemStatus == "infeasible":
        
        task=sdp.strategy.solver.int
        
        Violdual = "{:.2e}".format(task.getsolutioninfo(mosek.soltype.itr)[7])
        Objdual = "{:.2e}".format(task.getdualobj(mosek.soltype.itr))
        Normdual = "{:.2e}".format(task.getdualsolutionnorms(mosek.soltype.itr)[2],2)
        
        return False,Objdual,Normdual,Violdual
    else:
        return sol.problemStatus 

    
D=2

Codes=[
[1,0,1],[1,1,1],
[2,0,2],[2,1,1],[2,2,1],
[3,0,2],[3,1,1],[3,2,1],[3,3,1],
[4,0,2],[4,1,2],[4,2,2],[4,3,1],[4,4,1],
[5,0,3],[5,1,3],[5,2,2],[5,3,1],[5,4,1],[5,5,1],
[6,0,4],[6,1,3],[6,2,2],[6,3,2],[6,4,2],[6,5,1],[6,6,1],
[7,0,3],[7,1,3],[7,2,2],[7,3,2],[7,4,2],[7,5,1],[7,6,1],[7,7,1],
]

Codes=[
[1,0,1],[1,1,1],
[2,0,2],
[2,1,1],[2,2,1],
[3,0,2],[3,1,1],[3,2,1],[3,3,1],
#[4,0,2],
#[4,1,2],
#[4,2,2],[4,3,1],[4,4,1],
[5,0,3],
#[5,1,3],
[5,2,2],[5,3,1],[5,4,1],[5,5,1],
[6,0,4],
[6,1,3],[6,2,2],[6,3,2],[6,4,2],[6,5,1],[6,6,1],
[7,0,3],[7,1,3],[7,2,2],[7,3,2],[7,4,2],[7,5,1],[7,6,1],[7,7,1],
[8,0,4],[8,1,3],[8,2,3],[8,3,3],[8,4,2],[8,5,2],[8,6,2],[8,7,1],[8,8,1],
[9,0,4],[9,1,3],[9,2,3],[9,3,3],[9,4,2],[9,5,2],[9,6,2],[9,7,1],[9,8,1],[9,9,1],
[10,0,4],[10,1,4],[10,2,4],[10,3,3],[10,4,3],[10,5,2],[10,6,2],[10,7,2],[10,8,2],[10,9,1],[10,10,1]
]

#Codes=[[6,2,2]]
#Codes=[[7,7,1]]
#Codes=[[6,6,1]]
#Codes=[[10, 8, 3]]
#Codes=[[2,0,2]]
#### Existing qubit codes ####


for code in Codes:
    
    n,K,d=code
    p=n
    check=SDP(n,2**K,d,p,D)
    
    if check != True:
        print("%s=%s" % (code,check))

print("Done")



#### Not existing qubit codes (distance+1) ####

for code in Codes:
    
    n,K,d=code
    p=n
    check=SDP(n,2**K,d+1,p,D)
    
    #if check != False:
    print("[%s,%s,%s]=%s" % (code[0],code[1],code[2]+1,check))
# Out:
# [6, 6, 1]=unknown
# Done
# [1,0,2]=True
# [1,1,2]=(False, '1.50e+05', '1.00e+00', '0.00e+00')
# [2,0,3]=True
# [2,1,2]=(False, '2.00e+05', '2.00e+00', '0.00e+00')
# [2,2,2]=(False, '2.00e+05', '6.67e-01', '0.00e+00')
# [3,0,3]=True
# [3,1,2]=(False, '5.00e+04', '1.00e+00', '0.00e+00')
# [3,2,2]=(False, '5.00e+04', '3.33e-01', '0.00e+00')
# [3,3,2]=(False, '6.43e+04', '1.43e-01', '0.00e+00')
# [5,0,4]=True
# [5,2,3]=(False, '1.00e+00', '4.00e-06', '0.00e+00')
# [5,3,2]=(False, '1.00e+00', '9.33e-02', '1.96e-11')
# [5,4,2]=(False, '1.00e+00', '3.36e-01', '4.18e-12')
# [5,5,2]=(False, '1.00e+00', '6.97e-01', '2.39e-12')
# [6,0,5]=True
# [6,1,4]=(False, '3.00e+05', '2.00e+00', '0.00e+00')
# [6,2,3]=(False, '1.00e+00', '4.33e+00', '0.00e+00')
# [6,3,3]=(False, '1.00e+00', '6.03e+00', '0.00e+00')
# [6,4,3]=(False, '1.00e+00', '8.85e+00', '0.00e+00')
# [6,5,2]=(False, '1.00e+00', '4.01e-01', '6.85e-11')
# [6,6,2]=(False, '1.00e+00', '1.04e+00', '1.39e-09')
# [7,0,4]=True
# [7,1,4]=(False, '1.00e+00', '4.10e-01', '6.27e-13')
# [7,2,3]=(False, '1.00e+00', '3.46e+00', '1.61e-11')
# [7,3,3]=(False, '1.00e+00', '1.10e+01', '1.95e-10')
# [7,4,3]=(False, '1.00e+00', '8.25e+00', '1.90e-11')
# [7,5,2]=(False, '1.02e+00', '1.66e-01', '4.27e-09')
# [7,6,2]=(False, '9.98e-01', '2.54e+00', '1.81e-09')
# [7,7,2]=(False, '1.02e+00', '4.72e+00', '1.18e-08')
# [8,0,5]=True
# [8,1,4]=(False, '1.00e+00', '1.52e+00', '2.78e-12')
# [8,2,4]=(False, '1.00e+00', '5.06e-01', '3.55e-12')
# [8,3,4]=(False, '1.00e+00', '2.99e-01', '3.02e-11')
# [8,4,3]=(False, '1.26e+00', '3.20e+01', '1.22e-08')
# [8,5,3]=(False, '1.00e+00', '1.12e+02', '6.46e-10')
# [8,6,3]=(False, '1.00e+00', '1.92e+02', '3.16e-10')
# [8,7,2]=(False, '1.16e+00', '3.03e+00', '1.41e-08')
# [8,8,2]=(False, '1.44e+00', '3.24e+00', '3.41e-07')
# [9,0,5]=True
# [9,1,4]=(False, '9.88e-01', '1.24e+01', '8.90e-10')
# [9,2,4]=(False, '9.99e-01', '7.22e+00', '3.65e-10')
# [9,3,4]=(False, '1.00e+00', '3.67e+00', '1.64e-10')
# [9,4,3]=(False, '2.00e+00', '5.37e+01', '2.67e-08')
# [9,5,3]=(False, '1.01e+00', '2.15e+02', '2.85e-10')
# [9,6,3]=(False, '1.18e+00', '2.23e+02', '1.22e-09')
# [9,7,2]=(False, '1.33e+00', '2.03e-01', '4.71e-09')
# [9,8,2]=(False, '1.35e+00', '5.11e+00', '1.57e-09')
# [9,9,2]=(False, '-8.34e-01', '7.12e+00', '3.83e-09')
# [10,0,5]=True
# [10,1,5]=(False, '1.00e+00', '5.97e+00', '9.41e-11')
# [10,2,5]=(False, '9.88e-01', '4.49e+01', '1.25e-09')
# [10,3,4]=(False, '8.78e-01', '4.31e+00', '2.41e-08')
# [10,4,4]=(False, '3.89e+00', '1.01e+01', '4.77e-07')
# [10,5,3]=(False, '2.69e+00', '4.96e+02', '1.92e-07')
# [10,6,3]=(False, '4.63e+00', '3.80e+03', '7.77e-08')
# [10,7,3]=(False, '1.27e+00', '3.16e+01', '1.04e-08')
# [10,8,3]=(False, '2.38e+00', '2.07e+02', '1.75e-10')
# [10,9,2]=(False, '6.87e-01', '2.91e+00', '2.00e-09')
# [10,10,2]=(False, '-3.94e+00', '3.67e+00', '1.27e-10')
